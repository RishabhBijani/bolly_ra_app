# %%
#Fuzzy Matching 
#26th July 2025 

import pandas as pd
import os
from rapidfuzz import process, fuzz
import re

# === Load datasets ===
#NOTE: PLEASE ENSURE both, movies_random_sample.csv and bollywood_box_office_2010_2024.csv 
# are in Desktop/ra_app
box_office_path = os.path.expanduser("~/Desktop/ra_app/bollywood_box_office_2010_2024.csv")
movies_sample_path = os.path.expanduser("~/Desktop/ra_app/movies_random_sample.csv")

box_office_df = pd.read_csv(box_office_path)
movies_df = pd.read_csv(movies_sample_path)

# === Clean and normalize movie names ===
def clean_title(title):
    if pd.isna(title):
        return ""
    title = str(title).lower()
    title = re.sub(r'\([^)]*\)', '', title)  # Remove text in parentheses
    title = re.sub(r'[^a-z0-9\s]', '', title)  # Remove punctuation
    title = re.sub(r'\s+', ' ', title).strip()  # Normalize whitespace
    return title

# Add cleaned columns
movies_df["clean_original_title"] = movies_df["original_title"].apply(clean_title)
movies_df["clean_title_kaggle"] = movies_df["title_kaggle"].apply(clean_title)
box_office_df["clean_movie_name"] = box_office_df["movie_name"].apply(clean_title)

# === Match function ===
def match_movie(clean_title1, clean_title2, choices, threshold=70):
    match1 = process.extractOne(clean_title1, choices, scorer=fuzz.ratio) if clean_title1 else None
    match2 = process.extractOne(clean_title2, choices, scorer=fuzz.ratio) if clean_title2 else None
    
    best_match = None
    if match1 and match2:
        best_match = match1 if match1[1] >= match2[1] else match2
    elif match1:
        best_match = match1
    elif match2:
        best_match = match2
    
    if best_match and best_match[1] >= threshold:
        return best_match
    else:
        return None

# === Full Run: Match and print all 100 results ===
print("\n=== Full Fuzzy Matching Results (All 100 Movies) ===\n")

for idx, row in movies_df.iterrows():
    # Special case override: force NA for "Humsafar"
    if row['title_kaggle'].strip().lower() == "humsafar":
        print(f"🎬 {row['title_kaggle']}")
        print("🔎 Matched With: NA")
        print("🏆 Lifetime Collection: NA")
        print("-" * 60)
        continue

    match_result = match_movie(row["clean_original_title"], row["clean_title_kaggle"], box_office_df["clean_movie_name"])
    
    print(f"🎬 {row['title_kaggle']}")
    
    if match_result:
        matched_title_clean, score, match_idx = match_result
        matched_row = box_office_df.iloc[match_idx]
        print(f"🔎 Matched With: {matched_row['movie_name']} (Score: {score})")
        print(f"🏆 Lifetime Collection: {matched_row['lifetime_collection']}")
    else:
        print("🔎 Matched With: NA")
        print("🏆 Lifetime Collection: NA")
    
    print("-" * 60)

# === Store lifetime collection results ===
lifetime_collections = []

for idx, row in movies_df.iterrows():
    # Special case: force NA for "Humsafar"
    if row['title_kaggle'].strip().lower() == "humsafar":
        lifetime_collections.append(None)
        continue

    match_result = match_movie(row["clean_original_title"], row["clean_title_kaggle"], box_office_df["clean_movie_name"])
    
    if match_result:
        _, score, match_idx = match_result
        matched_row = box_office_df.iloc[match_idx]
        lifetime_collections.append(matched_row['lifetime_collection'])
    else:
        lifetime_collections.append(None)

# Add matched results to original DataFrame and save
movies_df["lifetime_collection_matched"] = lifetime_collections
output_path = os.path.expanduser("~/Desktop/ra_app/movies_random_sample.csv")
movies_df.to_csv(output_path, index=False)
print(f"\n✅ Lifetime collections appended and saved to: {output_path}")
# Out:
# === Full Fuzzy Matching Results (All 100 Movies) ===
#
# 🎬 Mere Pyare Prime Minister
# 🔎 Matched With: Merey Pyarey Prime Minister (Score: 96.15384615384616)
# 🏆 Lifetime Collection: 0.39 Cr
# ------------------------------------------------------------
# 🎬 Manikarnika: The Queen of Jhansi
# 🔎 Matched With: Manikarnika – The Queen Of Jhansi (Score: 100.0)
# 🏆 Lifetime Collection: 92.19 Cr
# ------------------------------------------------------------
# 🎬 Viceroy's House (film)
# 🔎 Matched With: NA
# 🏆 Lifetime Collection: NA
# ------------------------------------------------------------
# 🎬 3 Storeys
# 🔎 Matched With: 3 Storeys (Score: 100.0)
# 🏆 Lifetime Collection: 3.92 Cr
# ------------------------------------------------------------
# 🎬 Fatso!
# 🔎 Matched With: Fatso (Score: 100.0)
# 🏆 Lifetime Collection: 0.15 Cr
# ------------------------------------------------------------
# 🎬 Jigariyaa
# 🔎 Matched With: Jigariyaa (Score: 100.0)
# 🏆 Lifetime Collection: 0.16 Cr
# ------------------------------------------------------------
# 🎬 7 Khoon Maaf
# 🔎 Matched With: 7 Khoon Maaf (Score: 100.0)
# 🏆 Lifetime Collection: 17.69 Cr
# ------------------------------------------------------------
# 🎬 October (2018 film)
# 🔎 Matched With: October (Score: 100.0)
# 🏆 Lifetime Collection: 39.06 Cr
# ------------------------------------------------------------
# 🎬 The Ghazi Attack
# 🔎 Matched With: The Ghazi Attack (Score: 100.0)
# 🏆 Lifetime Collection: 20.3 Cr
# ------------------------------------------------------------
# 🎬 Khwaabb
# 🔎 Matched With: Khwaabb (Score: 100.0)
# 🏆 Lifetime Collection: 0.75 Cr
# ------------------------------------------------------------
# 🎬 W (2014 film)
# 🔎 Matched With: W (Score: 100.0)
# 🏆 Lifetime Collection: 0.04 Cr
# ------------------------------------------------------------
# 🎬 Yaaram (2019 film)
# 🔎 Matched With: #Yaaram (Score: 100.0)
# 🏆 Lifetime Collection: 0.03 Cr
# ------------------------------------------------------------
# 🎬 Happy Bhag Jayegi
# 🔎 Matched With: Happy Bhag Jayegi (Score: 100.0)
# 🏆 Lifetime Collection: 28.82 Cr
# ------------------------------------------------------------
# 🎬 Newton (film)
# 🔎 Matched With: Newton (Score: 100.0)
# 🏆 Lifetime Collection: 22.80 Cr
# ------------------------------------------------------------
# 🎬 Zero (2018 film)
# 🔎 Matched With: Zero (Score: 100.0)
# 🏆 Lifetime Collection: 90.28 Cr
# ------------------------------------------------------------
# 🎬 M Cream
# 🔎 Matched With: M Cream (Score: 100.0)
# 🏆 Lifetime Collection: 0.31 Cr
# ------------------------------------------------------------
# 🎬 Chennai Express
# 🔎 Matched With: Chennai Express (Score: 100.0)
# 🏆 Lifetime Collection: 227.13 Cr
# ------------------------------------------------------------
# 🎬 Student of the Year
# 🔎 Matched With: Student Of The Year (Score: 100.0)
# 🏆 Lifetime Collection: 70.00 Cr
# ------------------------------------------------------------
# 🎬 Bewakoofiyaan
# 🔎 Matched With: Bewakoofiyaan (Score: 100.0)
# 🏆 Lifetime Collection: 14.01 Cr
# ------------------------------------------------------------
# 🎬 Raanjhanaa
# 🔎 Matched With: Raanjhanaa (Score: 100.0)
# 🏆 Lifetime Collection: 60.35 Cr
# ------------------------------------------------------------
# 🎬 Kismat Love Paisa Dilli
# 🔎 Matched With: Kismet Love Paisa Dilli (Score: 100.0)
# 🏆 Lifetime Collection: 3.80 Cr
# ------------------------------------------------------------
# 🎬 Ek Tha Tiger
# 🔎 Matched With: Ek Tha Tiger (Score: 100.0)
# 🏆 Lifetime Collection: 198.78 Cr
# ------------------------------------------------------------
# 🎬 Crazy Cukkad Family
# 🔎 Matched With: Crazy Cukkad Family (Score: 100.0)
# 🏆 Lifetime Collection: 0.39 Cr
# ------------------------------------------------------------
# 🎬 Mary Kom (film)
# 🔎 Matched With: Mary Kom (Score: 100.0)
# 🏆 Lifetime Collection: 56.5 Cr
# ------------------------------------------------------------
# 🎬 Humsafar
# 🔎 Matched With: NA
# 🏆 Lifetime Collection: NA
# ------------------------------------------------------------
# 🎬 Coffee Bloom
# 🔎 Matched With: Coffee Bloom (Score: 100.0)
# 🏆 Lifetime Collection: 0.03 Cr
# ------------------------------------------------------------
# 🎬 Jai Gangaajal
# 🔎 Matched With: Jai Gangaajal (Score: 100.0)
# 🏆 Lifetime Collection: 32.63 Cr
# ------------------------------------------------------------
# 🎬 Aiyyaa
# 🔎 Matched With: Aiyyaa (Score: 100.0)
# 🏆 Lifetime Collection: 6.63 Cr
# ------------------------------------------------------------
# 🎬 Arjun Patiala
# 🔎 Matched With: Arjun Patiala (Score: 100.0)
# 🏆 Lifetime Collection: 6.62 Cr
# ------------------------------------------------------------
# 🎬 2 States (2014 film)
# 🔎 Matched With: 2 States (Score: 100.0)
# 🏆 Lifetime Collection: 102.13 Cr
# ------------------------------------------------------------
# 🎬 Zila Ghaziabad
# 🔎 Matched With: Zila Ghaziabad (Score: 100.0)
# 🏆 Lifetime Collection: 16 Cr
# ------------------------------------------------------------
# 🎬 Ek Paheli Leela
# 🔎 Matched With: Ek Paheli Leela (Score: 100.0)
# 🏆 Lifetime Collection: 26.57 Cr
# ------------------------------------------------------------
# 🎬 Brahman Naman
# 🔎 Matched With: NA
# 🏆 Lifetime Collection: NA
# ------------------------------------------------------------
# 🎬 Holiday: A Soldier Is Never Off Duty
# 🔎 Matched With: Holiday – A Soldier Is Never Off Duty (Score: 100.0)
# 🏆 Lifetime Collection: 112.45 Cr
# ------------------------------------------------------------
# 🎬 Sixteen (2013 Indian film)
# 🔎 Matched With: Sixteen (Score: 100.0)
# 🏆 Lifetime Collection: 1.44 Cr
# ------------------------------------------------------------
# 🎬 Dum Laga Ke Haisha
# 🔎 Matched With: Dum Laga Ke Haisha (Score: 100.0)
# 🏆 Lifetime Collection: 30.19 Cr
# ------------------------------------------------------------
# 🎬 Lootera
# 🔎 Matched With: Lootera (Score: 100.0)
# 🏆 Lifetime Collection: 29 Cr
# ------------------------------------------------------------
# 🎬 Shaadi Mein Zaroor Aana
# 🔎 Matched With: Shaadi Mein Zaroor Aana (Score: 100.0)
# 🏆 Lifetime Collection: 11.14 Cr
# ------------------------------------------------------------
# 🎬 Mumbhai Connection
# 🔎 Matched With: NA
# 🏆 Lifetime Collection: NA
# ------------------------------------------------------------
# 🎬 Golmaal Again
# 🔎 Matched With: Golmaal Again (Score: 100.0)
# 🏆 Lifetime Collection: 205.69 Cr
# ------------------------------------------------------------
# 🎬 Kaashi in Search of Ganga
# 🔎 Matched With: Kaashi – In Search of Ganga (Score: 100.0)
# 🏆 Lifetime Collection: 0.90 Cr
# ------------------------------------------------------------
# 🎬 Aashiqui 2
# 🔎 Matched With: Aashiqui 2 (Score: 100.0)
# 🏆 Lifetime Collection: 78.42 Cr
# ------------------------------------------------------------
# 🎬 Ladies vs Ricky Bahl
# 🔎 Matched With: Ladies VS Ricky Bahl (Score: 100.0)
# 🏆 Lifetime Collection: 32.97 Cr
# ------------------------------------------------------------
# 🎬 Jhalki
# 🔎 Matched With: Jhalki (Score: 100.0)
# 🏆 Lifetime Collection: 0.06 Cr
# ------------------------------------------------------------
# 🎬 Dil Bechara
# 🔎 Matched With: NA
# 🏆 Lifetime Collection: NA
# ------------------------------------------------------------
# 🎬 Article 15 (film)
# 🔎 Matched With: Article 15 (Score: 100.0)
# 🏆 Lifetime Collection: 65.45 Cr
# ------------------------------------------------------------
# 🎬 Total Siyapaa
# 🔎 Matched With: Total Siyapaa (Score: 100.0)
# 🏆 Lifetime Collection: 5.94 Cr
# ------------------------------------------------------------
# 🎬 Ramaiya Vastavaiya
# 🔎 Matched With: Ramaiya Vastavaiya (Score: 100.0)
# 🏆 Lifetime Collection: 36.3 Cr
# ------------------------------------------------------------
# 🎬 Photograph (film)
# 🔎 Matched With: Photograph (Score: 100.0)
# 🏆 Lifetime Collection: 1.29 Cr
# ------------------------------------------------------------
# 🎬 Kahaani
# 🔎 Matched With: Kahaani (Score: 100.0)
# 🏆 Lifetime Collection: 51.55 Cr
# ------------------------------------------------------------
# 🎬 Ankhon Dekhi
# 🔎 Matched With: Ankhon Dekhi (Score: 100.0)
# 🏆 Lifetime Collection: 0.74 Cr
# ------------------------------------------------------------
# 🎬 Shab (film)
# 🔎 Matched With: Shab (Score: 100.0)
# 🏆 Lifetime Collection: 0.21 Cr
# ------------------------------------------------------------
# 🎬 Omerta (film)
# 🔎 Matched With: Omerta (Score: 100.0)
# 🏆 Lifetime Collection: 3.56 Cr
# ------------------------------------------------------------
# 🎬 Chittagong (film)
# 🔎 Matched With: Chittagong (Score: 100.0)
# 🏆 Lifetime Collection: 0.19 Cr
# ------------------------------------------------------------
# 🎬 Phata Poster Nikhla Hero
# 🔎 Matched With: Phata Poster Nikhla Hero (Score: 100.0)
# 🏆 Lifetime Collection: 36.53 Cr
# ------------------------------------------------------------
# 🎬 Ab Tak Chhappan 2
# 🔎 Matched With: Ab Tak Chhappan 2 (Score: 100.0)
# 🏆 Lifetime Collection: 6.64 Cr
# ------------------------------------------------------------
# 🎬 F.A.L.T.U
# 🔎 Matched With: F.A.L.T.U (Score: 100.0)
# 🏆 Lifetime Collection: 24.57 Cr
# ------------------------------------------------------------
# 🎬 Bajirao Mastani
# 🔎 Matched With: Bajirao Mastani (Score: 100.0)
# 🏆 Lifetime Collection: 184.2 Cr
# ------------------------------------------------------------
# 🎬 Gollu Aur Pappu
# 🔎 Matched With: Gollu Aur Pappu (Score: 100.0)
# 🏆 Lifetime Collection: 0.01 Cr
# ------------------------------------------------------------
# 🎬 Tanu Weds Manu: Returns
# 🔎 Matched With: Tanu Weds Manu Returns (Score: 100.0)
# 🏆 Lifetime Collection: 150.8 Cr
# ------------------------------------------------------------
# 🎬 Ungli
# 🔎 Matched With: Ungli (Score: 100.0)
# 🏆 Lifetime Collection: 19.47 Cr
# ------------------------------------------------------------
# 🎬 Queen (2014 film)
# 🔎 Matched With: Queen (Score: 100.0)
# 🏆 Lifetime Collection: 61 Cr
# ------------------------------------------------------------
# 🎬 Parmanu: The Story of Pokhran
# 🔎 Matched With: Parmanu – The Story Of Pokhran (Score: 100.0)
# 🏆 Lifetime Collection: 65.89 Cr
# ------------------------------------------------------------
# 🎬 Azhar (film)
# 🔎 Matched With: Azhar (Score: 100.0)
# 🏆 Lifetime Collection: 33.03 Cr
# ------------------------------------------------------------
# 🎬 Sanju
# 🔎 Matched With: Sanju (Score: 100.0)
# 🏆 Lifetime Collection: 342.53 Cr
# ------------------------------------------------------------
# 🎬 Ae Dil Hai Mushkil
# 🔎 Matched With: Ae Dil Hai Mushkil (Score: 100.0)
# 🏆 Lifetime Collection: 112.48 Cr
# ------------------------------------------------------------
# 🎬 Satyameva Jayate (2018 film)
# 🔎 Matched With: Satyameva Jayate (Score: 100.0)
# 🏆 Lifetime Collection: 80.50 Cr
# ------------------------------------------------------------
# 🎬 Agent Vinod (2012 film)
# 🔎 Matched With: Agent Vinod (Score: 100.0)
# 🏆 Lifetime Collection: 43.29 Cr
# ------------------------------------------------------------
# 🎬 Phillauri (film)
# 🔎 Matched With: Phillauri (Score: 100.0)
# 🏆 Lifetime Collection: 27.1 Cr
# ------------------------------------------------------------
# 🎬 Tumhari Sulu
# 🔎 Matched With: Tumhari Sulu (Score: 100.0)
# 🏆 Lifetime Collection: 36.15 Cr
# ------------------------------------------------------------
# 🎬 I Love Desi
# 🔎 Matched With: I Love Desi (Score: 100.0)
# 🏆 Lifetime Collection: 0.003 Cr
# ------------------------------------------------------------
# 🎬 Dhoom 3
# 🔎 Matched With: Dhoom 3 (Score: 100.0)
# 🏆 Lifetime Collection: 284.27 Cr
# ------------------------------------------------------------
# 🎬 M.S. Dhoni: The Untold Story
# 🔎 Matched With: M.S. Dhoni – The Untold Story (Score: 100.0)
# 🏆 Lifetime Collection: 133.04 Cr
# ------------------------------------------------------------
# 🎬 Sons of Ram
# 🔎 Matched With: Sons of Ram (Score: 100.0)
# 🏆 Lifetime Collection: 0.19 Cr
# ------------------------------------------------------------
# 🎬 Halkaa
# 🔎 Matched With: Halkaa (Score: 100.0)
# 🏆 Lifetime Collection: 0.11 Cr
# ------------------------------------------------------------
# 🎬 Bhaiaji Superhit
# 🔎 Matched With: Bhaiaji Superhittt (Score: 94.11764705882352)
# 🏆 Lifetime Collection: 6.25 Cr
# ------------------------------------------------------------
# 🎬 Jagga Jasoos
# 🔎 Matched With: Jagga Jasoos (Score: 100.0)
# 🏆 Lifetime Collection: 54.16 Cr
# ------------------------------------------------------------
# 🎬 ?: A Question Mark
# 🔎 Matched With: NA
# 🏆 Lifetime Collection: NA
# ------------------------------------------------------------
# 🎬 Good Newwz
# 🔎 Matched With: Good Newwz (Score: 100.0)
# 🏆 Lifetime Collection: 205.14 Cr
# ------------------------------------------------------------
# 🎬 Ghayal: Once Again
# 🔎 Matched With: Ghayal Once Again (Score: 100.0)
# 🏆 Lifetime Collection: 35.7 Cr
# ------------------------------------------------------------
# 🎬 Mummy Punjabi
# 🔎 Matched With: Mummy Punjabi (Score: 100.0)
# 🏆 Lifetime Collection: 0.20 Cr
# ------------------------------------------------------------
# 🎬 Chakravyuh (2012 film)
# 🔎 Matched With: Chakravyuh (Score: 100.0)
# 🏆 Lifetime Collection: 18.42 Cr
# ------------------------------------------------------------
# 🎬 Mirzya (film)
# 🔎 Matched With: Mirzya (Score: 100.0)
# 🏆 Lifetime Collection: 10.43 Cr
# ------------------------------------------------------------
# 🎬 Dabangg 2
# 🔎 Matched With: Dabangg 2 (Score: 100.0)
# 🏆 Lifetime Collection: 155.00 Cr
# ------------------------------------------------------------
# 🎬 The Accidental Prime Minister (film)
# 🔎 Matched With: The Accidental Prime Minister (Score: 100.0)
# 🏆 Lifetime Collection: 22.65 Cr
# ------------------------------------------------------------
# 🎬 Desi Kattey
# 🔎 Matched With: Desi Kattey (Score: 100.0)
# 🏆 Lifetime Collection: 2.98 Cr
# ------------------------------------------------------------
# 🎬 Take It Easy (2015 film)
# 🔎 Matched With: Take It Easy (Score: 100.0)
# 🏆 Lifetime Collection: 0.36 Cr
# ------------------------------------------------------------
# 🎬 Bombairiya
# 🔎 Matched With: Bombairiya (Score: 100.0)
# 🏆 Lifetime Collection: 0.14 Cr
# ------------------------------------------------------------
# 🎬 Manjhi – The Mountain Man
# 🔎 Matched With: Manjhi The Mountain Man (Score: 100.0)
# 🏆 Lifetime Collection: 12.53 Cr
# ------------------------------------------------------------
# 🎬 Sanam Re
# 🔎 Matched With: Sanam Re (Score: 100.0)
# 🏆 Lifetime Collection: 27.74 Cr
# ------------------------------------------------------------
# 🎬 Luckhnowi Ishq
# 🔎 Matched With: NA
# 🏆 Lifetime Collection: NA
# ------------------------------------------------------------
# 🎬 Baat Bann Gayi
# 🔎 Matched With: Baat Bann Gayi (Score: 100.0)
# 🏆 Lifetime Collection: 0.15 Cr
# ------------------------------------------------------------
# 🎬 Jaane Kyun De Yaaron
# 🔎 Matched With: Jaane Kyun De Yaaron (Score: 100.0)
# 🏆 Lifetime Collection: 0.025 Cr
# ------------------------------------------------------------
# 🎬 Maatr
# 🔎 Matched With: Maatr (Score: 100.0)
# 🏆 Lifetime Collection: 2.31 Cr
# ------------------------------------------------------------
# 🎬 Hum Chaar
# 🔎 Matched With: Hum Chaar (Score: 100.0)
# 🏆 Lifetime Collection: 0.19 Cr
# ------------------------------------------------------------
# 🎬 Padmaavat
# 🔎 Matched With: Padmaavat (Score: 100.0)
# 🏆 Lifetime Collection: 302.15 Cr
# ------------------------------------------------------------
# 🎬 Badlapur (film)
# 🔎 Matched With: Badlapur (Score: 100.0)
# 🏆 Lifetime Collection: 50.07 Cr
# ------------------------------------------------------------
# 🎬 Baby (2015 Hindi film)
# 🔎 Matched With: Baby (Score: 100.0)
# 🏆 Lifetime Collection: 95.56 Cr
# ------------------------------------------------------------
# 🎬 The Silent Heroes
# 🔎 Matched With: The Silent Heroes (Score: 100.0)
# 🏆 Lifetime Collection: 0.11 Cr
# ------------------------------------------------------------
# 🎬 Coffee with D
# 🔎 Matched With: Coffee With D (Score: 100.0)
# 🏆 Lifetime Collection: 0.63 Cr
# ------------------------------------------------------------
#
# ✅ Lifetime collections appended and saved to: /Users/rishabhbijani/Desktop/ra_app/movies_random_sample.csv
